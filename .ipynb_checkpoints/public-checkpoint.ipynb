# %%
import seir_module.seir_module as sm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # SEIR model for prediction of the spread of COVID-19

# %% [markdown]
# SEIR is one of the compartmental models family, that describes the spread of epidemics. Different models of this family describe different kinds of an epidemic. For instance, the epidemic of an infection for which antibodies are produced. Or it can be epidemics either with or without an incubation period. Here I use the SEIR model that assumes both the infection has the incubation period and recovered people would have long-term immunity due to produced antibodies.
# All the compartmental models are first-order differential equations. The equation of the SEIR model:
#
# ${\frac {dS}{dt}}=\mu N-\mu S-\beta {\frac {I}{N}}S$
# ${\frac {dE}{dt}}=\beta {\frac {I}{N}}S-(\mu +a)E$
# ${\frac {dI}{dt}}=aE-(\gamma +\mu )I$
# ${\frac {dR}{dt}}=\gamma I-\mu R$
#
# $S(t)$ - (Susceptible) the number of people susceptible to the infection.
# $E(t)$ - (Exposed) the number of people who have already been infected.
# $I(t)$ - (Infectious) - the number of infected people.
# $R(t)$ - (Recovered) - the number of people who recovered after being infected.
# $N = S + E + I + R$ - is the number of all people under consideration that is the population size. It is assumed that the population is constant i.e. nobody can die due to the infection.
# $\mu$ - the natural mortality rate.
# $\alpha$ - the reciprocal of the incubation period.
# $\gamma$ - the reciprocal of the average recovery time.
# $\beta$ - coefficient of the intensity of contacts between people leading to infection.
#
# The life cycle of an individual in the SEIR model:

# %% [markdown]
# <img src="files/SEIR.PNG">

# %% [markdown]
# * Susceptible are non-infected people, moreover, they have never been infected. This means that they have no immunity and may be infected by Infectious individuals. $\beta$ is the probability of infection of the susceptible person during their contact with infectious.
#
# * When a person gets the infection it moves to the Exposed group. Exposed people are the people who have already been infected but don't have any symptoms yet due to the incubation period. Exposed people can't infect anyone. The moving of Susceptible people to Exposed is described by the first two equations of the SEIR model through the term $\beta {\frac {I}{N}}S$.
#
# * After being in the Exposed group during $1/\alpha$ days, the individual moves to the Infectious group. $1/\alpha$ is the incubation period.
#
# * After being in the Infectious group during $1/\gamma$ days, the individual moves to the Recovered group. The Recovered people don't have the infection symptoms anymore. They can't infect anyone and also can't be infected by the Infectious individual due to acquired immunity.
#
# * The SEIR model also includes the natural mortality in the population. The mortality is balanced by natural fertility, so the population size is constant. That means that the Recovered people will die someday and will be replaced by newborns who don't have immunity to the infection. That leads to a decrease in the size of the Recovered group little by little over time. The mortality intensity is described by the term $\mu$.
#
# The typical solution of the SEIR model:

# %%
S, E, I, R = sm.solve_seir(S0=10_000, E0=5, I0=10, R0=0,
                        betas=[0.04]*100000, gamma=0.01, alpha=sm.alpha, mu=0, times=np.arange(0, 1000,1))
plt.plot(S, color='yellow', label='Susceptible')
plt.plot(E, color='orange', label='Exposed')
plt.plot(I, color='red', label='Infectious')
plt.plot(R, color='green', label='Recovered')
plt.legend()

# %% [markdown]
# ### The solution of the equations
#
# Now we have all the equations of the model and have to solve them. Initial conditions of them and unknown coefficients are needed to do that.
# Let's simplify the model by assuming that we consider the model for a short period of time. That means that we can assume the mortality rate to be zero: $\mu = 0$. Also, the incubation period of COVID-19 is known and equal to 5.1 days.
# Now, having the simplified model, we can calculate all the remaining parameters using existing data. We will do it for each country and each region independently. Also, we have to replace all the differential operators in the equations with finite difference operators. So, we have:
#
# ${\Delta S}=-\beta {\frac {I}{N}}S$
# ${\Delta E}=\beta {\frac {I}{N}}S-aE$
# ${\Delta I}=aE-\gamma I$
# ${\Delta R}=\gamma I$
#
# The number of recovered people day by day is in our data. The number of infectious people is equal to the number of confirmed infection cases minus the number of recovered people. Using this information, we can find out the $\gamma$ parameter by optimization of the $\text{MALE}(\Delta R-\gamma I)$ function. Then, we can find $E$ from the third equation and $S$ using the fact that $S=N-I-E-R$ which means that Susceptible are all the people from the population except those who have already been infected and recovered.
# The term $\beta$ in the original SEIR model is assumed to be constant. However, it does not suit our case, because of lockdowns introduced in many countries. Lockdowns may lead to a decrease in the intensity of contact between people and consequently in the probability of infection which is the $\beta$ term. So, we replace the constant term with a $\beta(t)$ function.
# Having all the initial conditions, an optimization process may be used to calculate the $\beta(t)$ function.

# %% [markdown]
# ## Running of the model

# %%
# Original data:
# https://github.com/CSSEGISandData/COVID-19 - all countries 
# https://github.com/grwlf/COVID-19_plus_Russia - Russian regions
# 
# set your actual paths here
rus_directory='../COVID-19_plus_Russia/csse_covid_19_data/csse_covid_19_daily_reports/'
country_directory='../COVID-19/csse_covid_19_data/csse_covid_19_time_series/'

# %%
rus_regions = pd.read_csv('russia_regions.csv')
countries = pd.read_csv('countries.csv')

# %% [markdown]
# We will illustrate the results of applying the SEIR model on some real examples. The $\beta(t)$ function will be a step function with two steps.
# ### Moscow
# The first example is from Moscow. The left plot shows the number of both recovered and infected people, their sums predicted by the model. Also, the actual number of infected people is shown with a black curve. The right plot shows the optimized $\beta(t)$ function. The function has a significant jump on April 1. This date matches the date of the first lockdown introduced in Russia.

# %%
moscow_data = sm.read_data_for_country('Russia', 'Moscow', directory=rus_directory)
result = sm.run_train_test(moscow_data, 'Moscow, Russia', 
                           N=rus_regions[rus_regions.csse_province_state=='Moscow']['population'].iloc[0], 
                           beta_opt_func=sm.optimize_twostep_beta)

# %% [markdown]
# ### Italy
# The plot of the model predictions for Italy shows that the first jump of the $\beta(t)$ function happens on March 9. This date matches the date of the lockdown (https://en.wikipedia.org/wiki/2020_Italy_coronavirus_lockdown).

# %%
italy_data = sm.read_timeseries_for_country('Italy', directory=country_directory)
italy_result = sm.run_train_test(italy_data, 'Italy', 
                           N=countries[countries.ccse_name=='Italy']['population'].iloc[0], 
                           beta_opt_func=sm.optimize_twostep_beta)

# %% [markdown]
# ### Germany
# The first lockdown was introduced in Germany on March 22 (https://en.wikipedia.org/wiki/2020_coronavirus_pandemic_in_Germany). However, the first gap of the $\beta(t)$ function happens two days earlier, on March 20.

# %%
germany_data = sm.read_timeseries_for_country('Germany', directory=country_directory)
result = sm.run_train_test(germany_data, 'Germany', 
                           N=countries[countries.ccse_name=='Germany']['population'].iloc[0], 
                           beta_opt_func=sm.optimize_twostep_beta)

# %% [markdown]
# It can be seen from the plots above that the lockdowns lead to the decrease of the $\beta(t)$ function almost immediately. Moreover, the second decrease in the intensity of contacts happens after 1-2 weeks after the first one. It may be explained by the incubation periods that may be up to two weeks, although its median value is 5.1 days.
#
# And one more observation. The $\beta(t)$ function falls to the value of <0.05 in Italy and Germany. But it falls only to the value of 0.1 in Moscow. Does it mean that the lockdown works better in Germany and Italy than in Moscow? It is too early to make any conclusions but there is something to think about.

# %% [markdown]
# ## Training of the model

# %% [markdown]
# We used the two-step function of contact intensity to show how the model works with real data. However, it's not necessary to use so a complicated function for prediction. It's known that the values of all the functions of a first-order differential equation in the initial moment of time $t=0$ are enough to solve a Cauchy problem. That means that the solution of the SEIR model doesn't depend on the solution in the past. It depends on both the values of all the S, E, I, and R functions in the current moment and the model parameters. Hence, we can calculate the model parameters on some quite short period of time, and we also can assume $\beta(t)$ function to be a constant.
# We can perform cross-validation to ensure that the above assumptions are all true.
# Our cross-validation scheme:

# %% [markdown]
# <img src="files/cross_validation.png">

# %% [markdown]
# We tested the model on a parameters grid with the following values:
# The lengths of the time periods were $N \in \{5, 10, 15, 20, 30\}$ days.
# Types of the $\beta(t)$ function were a constant, one-step function, and two-step function. After calculating the model parameters, predictions were made up to 7 following days, and then the MALE error function was calculated. The results are shown in the pictures below (colors match the colors of the train-test split in the picture above).

# %% [markdown]
# <img src="files/cross_validation_functions.png">

# %% [markdown]
# The number of steps of the $\beta(t)$ function doesn't affect the result significantly. However, the longer the time interval the worst the results become.
# Average errors by folds:

# %% [markdown]
# <img src="files/means_cross_validation.png">

# %% [markdown]
# The best is the model with both a constant contact intensity function and a short time period. Having these results, I performed a cross-validation with the shorter time intervals $N \in \{2, 4, 7, 10, 14\}$ days and a constant $\beta(t)$ function. The results are in the plots below. The best result has the model with the shortest 2-point time interval.

# %% [markdown]
# <img src="files/constant_cross_validation.png">

# %% [markdown]
# Let's check how the model works with the different learning methods. We will use Moscow as the model city, train the model on real data before 2020-04-18 and predict for a week of April 18-25.
#
# #### Moscow, two-step contact intensity function

# %%
moscow_data = sm.read_data_for_country('Russia', 'Moscow', directory=rus_directory)
result = sm.run_train_test(moscow_data, 'Moscow, Russia', 
                           N=rus_regions[rus_regions.csse_province_state=='Moscow']['population'].iloc[0], 
                           test_fold_size=7,
                           beta_opt_func=sm.optimize_twostep_beta)

# %% [markdown]
# #### Moscow, constant contact intensity function, train time period is 5 days

# %%
moscow_data = sm.read_data_for_country('Russia', 'Moscow', directory=rus_directory)
result = sm.run_train_test(moscow_data, 'Moscow, Russia', 
                           N=rus_regions[rus_regions.csse_province_state=='Moscow']['population'].iloc[0], 
                           test_fold_size=7,
                           dot_number=5,
                           beta_opt_func=sm.optimize_zerostep_beta)

# %% [markdown]
# #### Moscow, constant contact intensity function, train time period is 2 days

# %%
moscow_data = sm.read_data_for_country('Russia', 'Moscow', directory=rus_directory)
result = sm.run_train_test(moscow_data, 'Moscow, Russia', 
                           N=rus_regions[rus_regions.csse_province_state=='Moscow']['population'].iloc[0], 
                           test_fold_size=7,
                           dot_number=2,
                           beta_opt_func=sm.optimize_zerostep_beta)

# %% [markdown]
# ## The final solution

# %% [markdown]
# The solution with the constant contact intensity function built by 2-time points was chosen as the final solution. As of 26.04.2020, the solution of the second stage of the competition has a 0.2736 score on the leaderboard by Russian regions. On the leaderboard by countries it has a 0.1431 score.
#
#
# Finally, we train the model with the chosen parameters and save its predictions:

# %%
subm=sm.train_all(rus_regions, countries, rus_directory, country_directory, dot_number=2)
# Out:
# ...
# 1. Training is starting: Afghanistan
# 2. Training is starting: Albania
# 	 Max number of infectious observations: max_confirmed = 712
# 3. Training is starting: Algeria
# 4. Training is starting: Andorra
# 	 Max number of infectious observations: max_confirmed = 738
# 5. Training is starting: Angola
# 	 Max number of infectious observations: max_confirmed = 25
# 6. Training is starting: Antigua and Barbuda
# 	 Max number of infectious observations: max_confirmed = 24
# 7. Training is starting: Azerbaijan
# 8. Training is starting: Argentina
# 9. Training is starting: Australia
# 10. Training is starting: Austria
# 11. Training is starting: Bahamas
# 	 Max number of infectious observations: max_confirmed = 78
# 12. Training is starting: Bahrain
# 13. Training is starting: Bangladesh
# 14. Training is starting: Armenia
# 15. Training is starting: Barbados
# 	 Max number of infectious observations: max_confirmed = 79
# 16. Training is starting: Belgium
# ...

# %%
subm.to_csv('submission.csv', index=False)

# %% [markdown]
# ## References
# Compartmental models https://en.wikipedia.org/wiki/Compartmental_models_in_epidemiology#The_SEIR_model
# An incubation period of COVID-19 https://annals.org/aim/fullarticle/2762808/incubation-period-coronavirus-disease-2019-covid-19-from-publicly-reported
