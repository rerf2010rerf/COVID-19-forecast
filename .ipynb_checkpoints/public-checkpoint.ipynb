# %% [markdown]
# # Модель SEIR для предсказания распространения COVID-19

# %% [markdown]
# SEIR - одна из семейства полигамных (англ. compartmental) моделей, описывающих распространение эпидемии. Различные модели этого семейства позволяют описывать различные типы заразы - например такие, для которых вырабатывается (или напротив, не вырабатывается иммунитет). Или такие, которые имеют (или не имеют) инкубационный период. В нашем случае для COVID-19 мы воспользуемся моделью с инкубационным периодом и вырабатывающимся у переболевших людей иммунитетом. <br>Все полигамные модели представляют собой дифференциальные уравнения первого порядка. Для SEIR оно выглядит так:<br>
#
# ${\frac {dS}{dt}}=\mu N-\mu S-\beta {\frac {I}{N}}S$
# ${\frac {dE}{dt}}=\beta {\frac {I}{N}}S-(\mu +a)E$
# ${\frac {dI}{dt}}=aE-(\gamma +\mu )I$
# ${\frac {dR}{dt}}=\gamma I-\mu R$
#
# Здесь: <br>
# $S(t)$ - (Susceptible) количество людей, подверженных заражению.
# $E(t)$ - (Exposed) количество носителей, т.е. заражённых людей, у которых болезнь еще не проявилась из-за инкубационного периода.
# $I(t)$ - (Infectious) - инфецированные.
# $R(t)$ - (Recovered) - выздоровевшие.
# $N = S + E + I + R$ - численность популяции. Она сохраняется постоянной, т.е. предполагается, что от болезни никто не умирает.
# $\mu$ - уровень естественной смертности.
# $\alpha$ - величина, обратная инкубационному периоду заболевания.
# $\gamma$ - величина, обратная среднему времени выздоровления.
# $\beta$ - коэффициент интенсивности контактов, приводящих к заражению.
#
# Жизненный цикл индивида в SEIR модели выглядит так:

# %% [markdown]
# <img src="files/SEIR.PNG">

# %% [markdown]
# * Здоровый, но ещё не переболевший человек (Susceptible) может заразиться от инфицированного (Infectious) человека. Вероятность, с которой здоровый человек заразится описывается параметром $\beta$.
# * Заразившийся человек переходит в состояние носителя инфекции (Exposed). Носители - это люди, у которых заболевание ещё не проявилось, т.е. у них протекает инкубационный период. Носители не могут никого заразить. Переход подверженных заболеванию людей в состояние носителей описывается двумя первыми уравнениями модели (посредством слагаемого $\beta {\frac {I}{N}}S$)
# * Через $1/\alpha$ дней (инкубационный период) после заражения носитель переходит в состояние инфицированного (Infectious).
# * Через $1/\gamma$ дней (время выздоровления), инфицированный переходит в состояние выздоровевшего (Recovered). У выздоровевшего человека вырабатывается иммунитет и он больше не может заразиться этой инфекцией.
# * Также, модель предусматривает естественную смертность населения в популяции. Смертность в SEIR модели сбалансирована рождаемостью, поэтому общая численность населения не меняется. Выздоровевшие люди рано или поздно умрут и заместятся новорожденными, которые иммунитет уже иметь не будут. Поэтому со временем количество выздоровевших людей в популяции уменьшается. Интенсивность смертности описывается параметром $\mu$.
#
# ### Решение модели
# Ну вот, уравнение модели есть, осталось его решить. Для этого нужны начальные условия для всех четырёх функций, а также неизвестные коэффициенты.
# Сделаем первое упрощение модели - т.к. мы рассматриваем развитие эпидемии на достаточно коротком промежутке времени, то будем считать, что естественная смертность населения равна нулю, т.е. $\mu = 0$.
# Также известно, что инкубационный период COVID-19 равен 5.1 день.
# Теперь, все остальные параметры для каждой страны и региона мы можем подобрать по имеющимся данным. После зануления коэффициента смертности $\mu$ и замены операторов дифференцирования на операторы конечной разности, имеем:
#
# ${ΔS}=-\beta {\frac {I}{N}}S$
# ${ΔE}=\beta {\frac {I}{N}}S-aE$
# ${ΔI}=aE-\gamma I$
# ${ΔR}=\gamma I$
#
# В качестве оператора конечной разности $Δ$ в этом решении использована двухсторонняя разность.
# Количество выздоровевших людей $R$ по дням есть в исходных данных, а количество инфицированных $I$ равно количеству подтвержденных случаев минус количество выздоровевших. Так что из последнего уравнения можем найти $\gamma$ с помощью оптимизации целевой функции $\text{MALE}(ΔR-\gamma I)$. Теперь, из третьего уравнения можно найти $E$, а затем и $S$, т.к. $S=N-I-E-R$ (т.е. заболеванию в любой момент времени подвержено всё населения, кроме тех, кто уже заразился и выздоровел).
#
# Для того, чтобы проследить, как карантинные мероприятия влияют на развитие эпидемии, немного усложним себе задачу и заменим коэффициент $\beta$ на функцию $\beta(t)$ - ведь по мере того, как в стране вводится карантин, интенсивность заражений должна падать, а значит в нашем случае $\beta$ не будет константой. Т.к. у нас уже есть все начальные условия для решения дифура, вопользуемся оптимизацией для поиска функции $\beta(t)$.

# %% [markdown]
# ## Запускаем модель

# %%
import seir_module.seir_module as sm
import numpy as np
import pandas as pd

# %%
# Расположение директорий с данными:
# https://github.com/CSSEGISandData/COVID-19 для всех стран 
# https://github.com/grwlf/COVID-19_plus_Russia для России
#
# Укажите здесь актуальные пути у вас. 
rus_directory='../COVID-19_plus_Russia/csse_covid_19_data/csse_covid_19_daily_reports/'
country_directory='../COVID-19/csse_covid_19_data/csse_covid_19_time_series/'

# %%
rus_regions = pd.read_csv('russia_regions.csv')
countries = pd.read_csv('countries.csv')

# %% [markdown]
# Чтобы проиллюстрировать работу модели SEIR на реальных данных, запустим подбор параметров на нескольких примерах. Функцию $\beta(t)$ сначала будем подбирать в виде ступенчатой - с двумя ступеньками. Посмотрим на примере Москвы, а также Италии и Германии.
# ### Москва
# Сначала на примере Москвы. На левом графике показаны модельные значений переболевших людей, заражённых, их суммы, а так же реальное количество обнаруженных случаев заражений (черный цвет). На левом показано, как изменяется значение $\beta(t)$. В Москве бета претерпевает значительный скачок 1 апреля, и следующий примерно через неделю. Дата первого скачка совпадает с введением в России активных мер самоизоляции.

# %%
moscow_data = sm.read_data_for_country('Russia', 'Moscow', directory=rus_directory)
result = sm.run_train_test(moscow_data, 'Moscow, Russia', 
                           N=rus_regions[rus_regions.csse_province_state=='Moscow']['population'].iloc[0], 
                           beta_opt_func=sm.optimize_twostep_beta)

# %% [markdown]
# ### Италия
# Аналогичный график для италии показывает, что первый скачок беты находится 9 марта, следующий - через 2 недели. Дата первого скачка также совпадает с датой введения в Италии 1 национального карантина (https://en.wikipedia.org/wiki/2020_Italy_coronavirus_lockdown)

# %%
italy_data = sm.read_timeseries_for_country('Italy', directory=country_directory)
result = sm.run_train_test(italy_data, 'Italy', 
                           N=countries[countries.ccse_name=='Italy']['population'].iloc[0], 
                           beta_opt_func=sm.optimize_twostep_beta)

# %% [markdown]
# ### Германия
# В Германии 22 марта были запрещены собрания, введено социальное дистанцирование и закрыты рестораны и другие заведения (https://en.wikipedia.org/wiki/2020_coronavirus_pandemic_in_Germany). Модель показывает первый скачок беты на 2 дня раньше, 20 марта.

# %%
germany_data = sm.read_timeseries_for_country('Germany', directory=country_directory)
result = sm.run_train_test(germany_data, 'Germany', 
                           N=countries[countries.ccse_name=='Germany']['population'].iloc[0], 
                           beta_opt_func=sm.optimize_twostep_beta)

# %% [markdown]
# Из поведения модели видно, что влияние введения карантина практически сразу приводит к модельному снижению количества контактов между людьми. Кроме того, второе снижение уровня контактов происходит через 1-2 недели. Возможно, это сказывается влияние инкубационного периода COVID-19, который как раз может достигать 2 недель (хотя медианный инкубационный период 5.1 равен день).
#
# Ещё одно наблюдение - если в Германии и Италии бета падает до значений <0.05, то в Москве оно остановилось в районе 0.2. Значит ли это, что у нас карантин работает хуже, чем в Италии и Германии? Наверное, утверждать это рано, но есть над чем подумать.

# %% [markdown]
# ## Обучение

# %% [markdown]
# Для того, чтобы посмотреть, как ведёт себя модель во времени на реальных данный, мы обучали её с двухступенчатой функцией интенсивности контактов. Однако, для предсказания на текущих данных, использовать такую сложную функцию нет необходимости. Как известно, для решения задачи Коши диффура первого порядка достаточно задать значения всех функций в начальный момент времени $t=0$. Т.е. решение модели SEIR в будущем не зависит от истории заражений в прошлом, а только от количества заражённых (вернее, всех функций S, E, I, R) в текущий момент времени и значений всех параметров уравнения. Потому для предсказания достаточно будет взять некоторый не очень длинный промежуток времени и подобрать на нём параметры. При этом бету на этом промежутке можно считать константой.
# Чтобы убедиться во всём вышесказанном на практике можно провести кросс-валидацию. Схема проведённой кросс-валидации:

# %% [markdown]
# <img src="files/cross_validation.png">

# %% [markdown]
# Для длин обучающих промежутков времени $N \in \{5, 10, 15, 20, 30\}$ дней и для трёх различных вариантов функций $\beta$ - константы, одноступенчатой и двухступенчатой, была вычислена модель на обучающых отрезках времени и посчитаны средние значений ошибки MALE за 7 последующих за обучающими дней. Результат получился такой (цвет графика соответствует цвету разбиения train-test на картинке выше):

# %% [markdown]
# <img src="files/cross_validation_functions.PNG">

# %% [markdown]
# Значительной влияния количеством ступенек у беты на ошибку нет, при этом при увеличении обучающего интервала качество предсказания падает.
#
# Усреднённые значения ошибки по всем фолдам:

# %% [markdown]
# <img src="files/means_cross_validation.PNG">

# %% [markdown]
# Лучше всего ведет себя константная функция контактов на маленьки обучающих промежутках. Также, я проделал кроссвалидацию с более мелким разбиением по длинам интервалов $N \in \{2, 4, 7, 10, 14\}$ и с константной бетой. Результаты ниже. Как ни странно, лучший средний результат показывает модель, обученная всего на двух точках. На первом графике показан результат по всем фолдам по отдельности, на втором - усреднённый по фолдам.

# %% [markdown]
# <img src="files/constant_cross_validation.PNG">

# %% [markdown]
# И посмотрим теперь, как ведёт себя модель на предсказании при различных способах обучения на примере Москвы. Для этого будем обучать модель на данных до 2020-04-18 и предсказывать на неделю с 18 по 25 апреля.
#
# #### Москва, двухступенчатая функция контактов

# %%
moscow_data = sm.read_data_for_country('Russia', 'Moscow', directory=rus_directory)
result = sm.run_train_test(moscow_data, 'Moscow, Russia', 
                           N=rus_regions[rus_regions.csse_province_state=='Moscow']['population'].iloc[0], 
                           test_fold_size=7,
                           beta_opt_func=sm.optimize_twostep_beta)

# %% [markdown]
# #### Москва, константная функция контактов, период обучения = 5 дней

# %%
moscow_data = sm.read_data_for_country('Russia', 'Moscow', directory=rus_directory)
result = sm.run_train_test(moscow_data, 'Moscow, Russia', 
                           N=rus_regions[rus_regions.csse_province_state=='Moscow']['population'].iloc[0], 
                           test_fold_size=7,
                           dot_number=5,
                           beta_opt_func=sm.optimize_zerostep_beta)

# %% [markdown]
# #### Москва, константная функция контактов, период обучения = 2 дня

# %%
moscow_data = sm.read_data_for_country('Russia', 'Moscow', directory=rus_directory)
result = sm.run_train_test(moscow_data, 'Moscow, Russia', 
                           N=rus_regions[rus_regions.csse_province_state=='Moscow']['population'].iloc[0], 
                           test_fold_size=7,
                           dot_number=2,
                           beta_opt_func=sm.optimize_zerostep_beta)

# %% [markdown]
# ## Финальное решение

# %% [markdown]
# В качестве финального решения было выбрано решение с константной функцией контаков, построенное под двум точкам. По состоянию на 26.04.2020 решение второго этапа соревнования на лидерборде по регионам России даёт оценку $0.2736$, а на лидерборде по странам $0.1431$
#
# Обучаем модель с выбранными параметрами и сохраняем:

# %%
subm=sm.train_all(rus_regions, countries, rus_directory, country_directory, dot_number=2)
# Out:
# HBox(children=(IntProgress(value=0, max=169), HTML(value='')))
# 1. Начинаем тренировать страну Afghanistan
# 2. Начинаем тренировать страну Albania
# 	 Максимальное количство заражённых: max_confirmed = 712
# 3. Начинаем тренировать страну Algeria
# 4. Начинаем тренировать страну Andorra
# 	 Максимальное количство заражённых: max_confirmed = 738
# 5. Начинаем тренировать страну Angola
# 	 Максимальное количство заражённых: max_confirmed = 25
# 6. Начинаем тренировать страну Antigua and Barbuda
# 	 Максимальное количство заражённых: max_confirmed = 24
# 7. Начинаем тренировать страну Azerbaijan
# 8. Начинаем тренировать страну Argentina
# 9. Начинаем тренировать страну Australia
# 10. Начинаем тренировать страну Austria
# 11. Начинаем тренировать страну Bahamas
# 	 Максимальное количство заражённых: max_confirmed = 78
# 12. Начинаем тренировать страну Bahrain
# 13. Начинаем тренировать страну Bangladesh
# 14. Начинаем тренировать страну Armenia
# 15. Начинаем тренировать страну Barbados
# 	 Максимальное количство заражённых: max_confirmed = 79
# 16. Начинаем тренировать страну Belgium
# 17. Начинаем тренировать страну Bhutan
# 	 Максимальное количство заражённых: max_confirmed = 7
# 18. Начинаем тренировать страну Bolivia
# 	 Максимальное количство заражённых: max_confirmed = 866
# 19. Начинаем тренировать страну Bosnia and Herzegovina
# 20. Начинаем тренировать страну Brazil
# 21. Начинаем тренировать страну Belize
# 	 Максимальное количство заражённых: max_confirmed = 18
# 22. Начинаем тренировать страну Brunei
# 	 Максимальное количство заражённых: max_confirmed = 138
# 23. Начинаем тренировать страну Bulgaria
# 24. Начинаем тренировать страну Belarus
# 25. Начинаем тренировать страну Cambodia
# 	 Максимальное количство заражённых: max_confirmed = 122
# 26. Начинаем тренировать страну Cameroon
# 27. Начинаем тренировать страну Canada
# 28. Начинаем тренировать страну Cabo Verde
# 	 Максимальное количство заражённых: max_confirmed = 90
# 29. Начинаем тренировать страну Central African Republic
# 	 Максимальное количство заражённых: max_confirmed = 16
# 30. Начинаем тренировать страну Sri Lanka
# 	 Максимальное количство заражённых: max_confirmed = 460
# 31. Начинаем тренировать страну Chad
# 	 Максимальное количство заражённых: max_confirmed = 46
# 32. Начинаем тренировать страну Chile
# 33. Начинаем тренировать страну China
# 34. Начинаем тренировать страну Taiwan*
# 	 Максимальное количство заражённых: max_confirmed = 429
# 35. Начинаем тренировать страну Colombia
# 36. Начинаем тренировать страну Congo (Brazzaville)
# 	 Максимальное количство заражённых: max_confirmed = 200
# 37. Начинаем тренировать страну Congo (Kinshasa)
# 	 Максимальное количство заражённых: max_confirmed = 416
# 38. Начинаем тренировать страну Costa Rica
# 	 Максимальное количство заражённых: max_confirmed = 693
# 39. Начинаем тренировать страну Croatia
# 40. Начинаем тренировать страну Cuba
# 41. Начинаем тренировать страну Cyprus
# 	 Максимальное количство заражённых: max_confirmed = 810
# 42. Начинаем тренировать страну Czechia
# 43. Начинаем тренировать страну Benin
# 	 Максимальное количство заражённых: max_confirmed = 54
# 44. Начинаем тренировать страну Denmark
# 45. Начинаем тренировать страну Dominica
# 	 Максимальное количство заражённых: max_confirmed = 16
# 46. Начинаем тренировать страну Dominican Republic
# 47. Начинаем тренировать страну Ecuador
# 48. Начинаем тренировать страну El Salvador
# 	 Максимальное количство заражённых: max_confirmed = 274
# 49. Начинаем тренировать страну Equatorial Guinea
# 	 Максимальное количство заражённых: max_confirmed = 258
# 50. Начинаем тренировать страну Ethiopia
# 	 Максимальное количство заражённых: max_confirmed = 122
# 51. Начинаем тренировать страну Eritrea
# 	 Максимальное количство заражённых: max_confirmed = 39
# 52. Начинаем тренировать страну Estonia
# 53. Начинаем тренировать страну Fiji
# 	 Максимальное количство заражённых: max_confirmed = 18
# 54. Начинаем тренировать страну Finland
# 55. Начинаем тренировать страну France
# 56. Начинаем тренировать страну Djibouti
# 57. Начинаем тренировать страну Gabon
# 	 Максимальное количство заражённых: max_confirmed = 176
# 58. Начинаем тренировать страну Georgia
# 	 Максимальное количство заражённых: max_confirmed = 456
# 59. Начинаем тренировать страну Gambia
# 	 Максимальное количство заражённых: max_confirmed = 10
# 60. Начинаем тренировать страну Germany
# 61. Начинаем тренировать страну Ghana
# 62. Начинаем тренировать страну Greece
# 63. Начинаем тренировать страну Grenada
# 	 Максимальное количство заражённых: max_confirmed = 18
# 64. Начинаем тренировать страну Guatemala
# 	 Максимальное количство заражённых: max_confirmed = 473
# 65. Начинаем тренировать страну Guinea
# 	 Максимальное количство заражённых: max_confirmed = 996
# 66. Начинаем тренировать страну Guyana
# 	 Максимальное количство заражённых: max_confirmed = 73
# 67. Начинаем тренировать страну Haiti
# 	 Максимальное количство заражённых: max_confirmed = 72
# 68. Начинаем тренировать страну Holy See
# 	 Максимальное количство заражённых: max_confirmed = 9
# 69. Начинаем тренировать страну Honduras
# 	 Максимальное количство заражённых: max_confirmed = 627
# 70. Начинаем тренировать страну Hungary
# 71. Начинаем тренировать страну Iceland
# 72. Начинаем тренировать страну India
# 73. Начинаем тренировать страну Indonesia
# 74. Начинаем тренировать страну Iran
# 75. Начинаем тренировать страну Iraq
# 76. Начинаем тренировать страну Ireland
# 77. Начинаем тренировать страну Israel
# 78. Начинаем тренировать страну Italy
# 79. Начинаем тренировать страну Cote d'Ivoire
# 80. Начинаем тренировать страну Jamaica
# 	 Максимальное количство заражённых: max_confirmed = 305
# 81. Начинаем тренировать страну Japan
# 82. Начинаем тренировать страну Kazakhstan
# 83. Начинаем тренировать страну Jordan
# 	 Максимальное количство заражённых: max_confirmed = 444
# 84. Начинаем тренировать страну Kenya
# 	 Максимальное количство заражённых: max_confirmed = 343
# 85. Начинаем тренировать страну Korea, South
# 86. Начинаем тренировать страну Kuwait
# 87. Начинаем тренировать страну Kyrgyzstan
# 	 Максимальное количство заражённых: max_confirmed = 665
# 88. Начинаем тренировать страну Laos
# 	 Максимальное количство заражённых: max_confirmed = 19
# 89. Начинаем тренировать страну Lebanon
# 	 Максимальное количство заражённых: max_confirmed = 704
# 90. Начинаем тренировать страну Latvia
# 	 Максимальное количство заражённых: max_confirmed = 804
# 91. Начинаем тренировать страну Liberia
# 	 Максимальное количство заражённых: max_confirmed = 120
# 92. Начинаем тренировать страну Libya
# 	 Максимальное количство заражённых: max_confirmed = 61
# 93. Начинаем тренировать страну Liechtenstein
# 	 Максимальное количство заражённых: max_confirmed = 81
# 94. Начинаем тренировать страну Lithuania
# 95. Начинаем тренировать страну Luxembourg
# 96. Начинаем тренировать страну Madagascar
# 	 Максимальное количство заражённых: max_confirmed = 123
# 97. Начинаем тренировать страну Malaysia
# 98. Начинаем тренировать страну Maldives
# 	 Максимальное количство заражённых: max_confirmed = 177
# 99. Начинаем тренировать страну Malta
# 	 Максимальное количство заражённых: max_confirmed = 448
# 100. Начинаем тренировать страну Mauritania
# 	 Максимальное количство заражённых: max_confirmed = 7
# 101. Начинаем тренировать страну Mauritius
# 	 Максимальное количство заражённых: max_confirmed = 331
# 102. Начинаем тренировать страну Mexico
# 103. Начинаем тренировать страну Monaco
# 	 Максимальное количство заражённых: max_confirmed = 94
# 104. Начинаем тренировать страну Mongolia
# 	 Максимальное количство заражённых: max_confirmed = 37
# 105. Начинаем тренировать страну Moldova
# 106. Начинаем тренировать страну Montenegro
# 	 Максимальное количство заражённых: max_confirmed = 320
# 107. Начинаем тренировать страну Morocco
# 108. Начинаем тренировать страну Mozambique
# 	 Максимальное количство заражённых: max_confirmed = 70
# 109. Начинаем тренировать страну Oman
# 110. Начинаем тренировать страну Namibia
# 	 Максимальное количство заражённых: max_confirmed = 16
# 111. Начинаем тренировать страну Nepal
# 	 Максимальное количство заражённых: max_confirmed = 49
# 112. Начинаем тренировать страну Netherlands
# 113. Начинаем тренировать страну New Zealand
# 114. Начинаем тренировать страну Nicaragua
# 	 Максимальное количство заражённых: max_confirmed = 12
# 115. Начинаем тренировать страну Niger
# 	 Максимальное количство заражённых: max_confirmed = 684
# 116. Начинаем тренировать страну Nigeria
# 117. Начинаем тренировать страну Norway
# 118. Начинаем тренировать страну Pakistan
# 119. Начинаем тренировать страну Panama
# 120. Начинаем тренировать страну Papua New Guinea
# 	 Максимальное количство заражённых: max_confirmed = 8
# 121. Начинаем тренировать страну Paraguay
# 	 Максимальное количство заражённых: max_confirmed = 228
# 122. Начинаем тренировать страну Peru
# 123. Начинаем тренировать страну Philippines
# 124. Начинаем тренировать страну Poland
# 125. Начинаем тренировать страну Portugal
# 126. Начинаем тренировать страну Timor-Leste
# 	 Максимальное количство заражённых: max_confirmed = 24
# 127. Начинаем тренировать страну Qatar
# 128. Начинаем тренировать страну Romania
# 129. Начинаем тренировать страну Russia
# 130. Начинаем тренировать страну Rwanda
# 	 Максимальное количство заражённых: max_confirmed = 183
# 131. Начинаем тренировать страну Saint Lucia
# 	 Максимальное количство заражённых: max_confirmed = 15
# 132. Начинаем тренировать страну Saint Vincent and the Grenadines
# 	 Максимальное количство заражённых: max_confirmed = 14
# 133. Начинаем тренировать страну San Marino
# 	 Максимальное количство заражённых: max_confirmed = 513
# 134. Начинаем тренировать страну Saudi Arabia
# 135. Начинаем тренировать страну Senegal
# 	 Максимальное количство заражённых: max_confirmed = 614
# 136. Начинаем тренировать страну Serbia
# 137. Начинаем тренировать страну Seychelles
# 	 Максимальное количство заражённых: max_confirmed = 11
# 138. Начинаем тренировать страну Singapore
# 139. Начинаем тренировать страну Slovakia
# 140. Начинаем тренировать страну Vietnam
# 	 Максимальное количство заражённых: max_confirmed = 270
# 141. Начинаем тренировать страну Slovenia
# 142. Начинаем тренировать страну Somalia
# 	 Максимальное количство заражённых: max_confirmed = 390
# 143. Начинаем тренировать страну South Africa
# 144. Начинаем тренировать страну Zimbabwe
# 	 Максимальное количство заражённых: max_confirmed = 31
# 145. Начинаем тренировать страну Spain
# 146. Начинаем тренировать страну Sudan
# 	 Максимальное количство заражённых: max_confirmed = 213
# 147. Начинаем тренировать страну Suriname
# 	 Максимальное количство заражённых: max_confirmed = 10
# 148. Начинаем тренировать страну Eswatini
# 	 Максимальное количство заражённых: max_confirmed = 56
# 149. Начинаем тренировать страну Sweden
# 150. Начинаем тренировать страну Switzerland
# 151. Начинаем тренировать страну Syria
# 	 Максимальное количство заражённых: max_confirmed = 42
# 152. Начинаем тренировать страну Thailand
# 153. Начинаем тренировать страну Togo
# 	 Максимальное количство заражённых: max_confirmed = 96
# 154. Начинаем тренировать страну Trinidad and Tobago
# 	 Максимальное количство заражённых: max_confirmed = 115
# 155. Начинаем тренировать страну United Arab Emirates
# 156. Начинаем тренировать страну Tunisia
# 	 Максимальное количство заражённых: max_confirmed = 939
# 157. Начинаем тренировать страну Turkey
# 158. Начинаем тренировать страну Uganda
# 	 Максимальное количство заражённых: max_confirmed = 75
# 159. Начинаем тренировать страну Ukraine
# 160. Начинаем тренировать страну North Macedonia
# 161. Начинаем тренировать страну Egypt
# 162. Начинаем тренировать страну United Kingdom
# 163. Начинаем тренировать страну Tanzania
# 	 Максимальное количство заражённых: max_confirmed = 299
# 164. Начинаем тренировать страну US
# 165. Начинаем тренировать страну Burkina Faso
# 	 Максимальное количство заражённых: max_confirmed = 629
# 166. Начинаем тренировать страну Uruguay
# 	 Максимальное количство заражённых: max_confirmed = 596
# 167. Начинаем тренировать страну Uzbekistan
# 168. Начинаем тренировать страну Venezuela
# 	 Максимальное количство заражённых: max_confirmed = 323
# 169. Начинаем тренировать страну Zambia
# 	 Максимальное количство заражённых: max_confirmed = 84
# HBox(children=(IntProgress(value=0, max=85), HTML(value='')))
# 1. Начинаем тренировать регион России Altayskiy kray
# 	 Максимальное количство заражённых: max_confirmed = 215
# 2. Начинаем тренировать регион России Amursk oblast
# 	 Максимальное количство заражённых: max_confirmed = 33
# 3. Начинаем тренировать регион России Arkhangelsk oblast
# 	 Максимальное количство заражённых: max_confirmed = 147
# 4. Начинаем тренировать регион России Astrahan oblast
# 	 Максимальное количство заражённых: max_confirmed = 211
# 5. Начинаем тренировать регион России Belgorod oblast
# 	 Максимальное количство заражённых: max_confirmed = 221
# 6. Начинаем тренировать регион России Briansk oblast
# 	 Максимальное количство заражённых: max_confirmed = 521
# 7. Начинаем тренировать регион России Vladimir oblast
# 	 Максимальное количство заражённых: max_confirmed = 426
# 8. Начинаем тренировать регион России Volgograd oblast
# 	 Максимальное количство заражённых: max_confirmed = 212
# 9. Начинаем тренировать регион России Vologda oblast
# 	 Максимальное количство заражённых: max_confirmed = 138
# 10. Начинаем тренировать регион России Voronezh oblast
# 	 Максимальное количство заражённых: max_confirmed = 313
# 11. Начинаем тренировать регион России Moscow
# 12. Начинаем тренировать регион России Saint Petersburg
# 13. Начинаем тренировать регион России Sevastopol
# 	 Максимальное количство заражённых: max_confirmed = 26
# 14. Начинаем тренировать регион России Jewish Autonomous oblast
# 	 Максимальное количство заражённых: max_confirmed = 86
# 15. Начинаем тренировать регион России Zabaykalskiy kray
# 	 Максимальное количство заражённых: max_confirmed = 83
# 16. Начинаем тренировать регион России Ivanovo oblast
# 	 Максимальное количство заражённых: max_confirmed = 263
# 17. Начинаем тренировать регион России Irkutsk oblast
# 	 Максимальное количство заражённых: max_confirmed = 85
# 18. Начинаем тренировать регион России Kaliningrad oblast
# 	 Максимальное количство заражённых: max_confirmed = 210
# 19. Начинаем тренировать регион России Kaluga oblast
# 	 Максимальное количство заражённых: max_confirmed = 513
# 20. Начинаем тренировать регион России Kamchatskiy kray
# 	 Максимальное количство заражённых: max_confirmed = 87
# 21. Начинаем тренировать регион России Kemerovo oblast
# 	 Максимальное количство заражённых: max_confirmed = 82
# 22. Начинаем тренировать регион России Kirov oblast
# 	 Максимальное количство заражённых: max_confirmed = 316
# 23. Начинаем тренировать регион России Kostroma oblast
# 	 Максимальное количство заражённых: max_confirmed = 137
# 24. Начинаем тренировать регион России Krasnodarskiy kray
# 	 Максимальное количство заражённых: max_confirmed = 707
# 25. Начинаем тренировать регион России Krasnoyarskiy kray
# 	 Максимальное количство заражённых: max_confirmed = 467
# 26. Начинаем тренировать регион России Kurgan oblast
# 	 Максимальное количство заражённых: max_confirmed = 27
# 27. Начинаем тренировать регион России Kursk oblast
# 	 Максимальное количство заражённых: max_confirmed = 389
# 28. Начинаем тренировать регион России Leningradskaya oblast
# 	 Максимальное количство заражённых: max_confirmed = 658
# 29. Начинаем тренировать регион России Lipetsk oblast
# 	 Максимальное количство заражённых: max_confirmed = 284
# 30. Начинаем тренировать регион России Magadan oblast
# 	 Максимальное количство заражённых: max_confirmed = 87
# 31. Начинаем тренировать регион России Moscow oblast
# 32. Начинаем тренировать регион России Murmansk oblast
# 	 Максимальное количство заражённых: max_confirmed = 856
# 33. Начинаем тренировать регион России Nenetskiy autonomous oblast
# 	 Максимальное количство заражённых: max_confirmed = 1
# 34. Начинаем тренировать регион России Nizhegorodskaya oblast
# 35. Начинаем тренировать регион России Novgorod oblast
# 	 Максимальное количство заражённых: max_confirmed = 186
# 36. Начинаем тренировать регион России Novosibirsk oblast
# 	 Максимальное количство заражённых: max_confirmed = 247
# 37. Начинаем тренировать регион России Omsk oblast
# 	 Максимальное количство заражённых: max_confirmed = 58
# 38. Начинаем тренировать регион России Orenburg oblast
# 	 Максимальное количство заражённых: max_confirmed = 361
# 39. Начинаем тренировать регион России Orel oblast
# 	 Максимальное количство заражённых: max_confirmed = 321
# 40. Начинаем тренировать регион России Pensa oblast
# 	 Максимальное количство заражённых: max_confirmed = 255
# 41. Начинаем тренировать регион России Perm oblast
# 	 Максимальное количство заражённых: max_confirmed = 373
# 42. Начинаем тренировать регион России Primorskiy kray
# 	 Максимальное количство заражённых: max_confirmed = 254
# 43. Начинаем тренировать регион России Pskov oblast
# 	 Максимальное количство заражённых: max_confirmed = 93
# 44. Начинаем тренировать регион России Republic of Adygeia
# 	 Максимальное количство заражённых: max_confirmed = 119
# 45. Начинаем тренировать регион России Altay republic
# 	 Максимальное количство заражённых: max_confirmed = 14
# 46. Начинаем тренировать регион России Republic of Bashkortostan
# 	 Максимальное количство заражённых: max_confirmed = 490
# 47. Начинаем тренировать регион России Republic of Buriatia
# 	 Максимальное количство заражённых: max_confirmed = 180
# 48. Начинаем тренировать регион России Republic of Dagestan
# 	 Максимальное количство заражённых: max_confirmed = 724
# 49. Начинаем тренировать регион России Ingushetia republic
# 	 Максимальное количство заражённых: max_confirmed = 515
# 50. Начинаем тренировать регион России Republic of Kabardino-Balkaria
# 	 Максимальное количство заражённых: max_confirmed = 272
# 51. Начинаем тренировать регион России Republic of Kalmykia
# 	 Максимальное количство заражённых: max_confirmed = 122
# 52. Начинаем тренировать регион России Republic of Karachaevo-Cherkessia
# 	 Максимальное количство заражённых: max_confirmed = 240
# 53. Начинаем тренировать регион России Republic of Karelia
# 	 Максимальное количство заражённых: max_confirmed = 42
# 54. Начинаем тренировать регион России Komi republic
# 	 Максимальное количство заражённых: max_confirmed = 561
# 55. Начинаем тренировать регион России Republic of Crimea
# 	 Максимальное количство заражённых: max_confirmed = 57
# 56. Начинаем тренировать регион России Republic of Mariy El
# 	 Максимальное количство заражённых: max_confirmed = 407
# 57. Начинаем тренировать регион России Republic of Mordovia
# 	 Максимальное количство заражённых: max_confirmed = 469
# 58. Начинаем тренировать регион России Saha republic
# 	 Максимальное количство заражённых: max_confirmed = 141
# 59. Начинаем тренировать регион России Republic of North Osetia - Alania
# 	 Максимальное количство заражённых: max_confirmed = 305
# 60. Начинаем тренировать регион России Republic of Tatarstan
# 	 Максимальное количство заражённых: max_confirmed = 491
# 61. Начинаем тренировать регион России Republic of Tyva
# 	 Максимальное количство заражённых: max_confirmed = 24
# 62. Начинаем тренировать регион России Republic of Udmurtia
# 	 Максимальное количство заражённых: max_confirmed = 193
# 63. Начинаем тренировать регион России Republic of Hakassia
# 	 Максимальное количство заражённых: max_confirmed = 151
# 64. Начинаем тренировать регион России Chechen republic
# 	 Максимальное количство заражённых: max_confirmed = 387
# 65. Начинаем тренировать регион России Rostov oblast
# 	 Максимальное количство заражённых: max_confirmed = 584
# 66. Начинаем тренировать регион России Ryazan oblast
# 	 Максимальное количство заражённых: max_confirmed = 539
# 67. Начинаем тренировать регион России Samara oblast
# 	 Максимальное количство заражённых: max_confirmed = 209
# 68. Начинаем тренировать регион России Saratov oblast
# 	 Максимальное количство заражённых: max_confirmed = 265
# 69. Начинаем тренировать регион России Sakhalin oblast
# 	 Максимальное количство заражённых: max_confirmed = 20
# 70. Начинаем тренировать регион России Sverdlov oblast
# 	 Максимальное количство заражённых: max_confirmed = 337
# 71. Начинаем тренировать регион России Smolensk oblast
# 	 Максимальное количство заражённых: max_confirmed = 279
# 72. Начинаем тренировать регион России Stavropolskiy kray
# 	 Максимальное количство заражённых: max_confirmed = 385
# 73. Начинаем тренировать регион России Tambov oblast
# 	 Максимальное количство заражённых: max_confirmed = 343
# 74. Начинаем тренировать регион России Tver oblast
# 	 Максимальное количство заражённых: max_confirmed = 441
# 75. Начинаем тренировать регион России Tomsk oblast
# 	 Максимальное количство заражённых: max_confirmed = 66
# 76. Начинаем тренировать регион России Tula oblast
# 	 Максимальное количство заражённых: max_confirmed = 578
# 77. Начинаем тренировать регион России Tumen oblast
# 	 Максимальное количство заражённых: max_confirmed = 374
# 78. Начинаем тренировать регион России Ulianovsk oblast
# 	 Максимальное количство заражённых: max_confirmed = 280
# 79. Начинаем тренировать регион России Habarovskiy kray
# 	 Максимальное количство заражённых: max_confirmed = 379
# 80. Начинаем тренировать регион России Hanty-Mansiyskiy AO
# 	 Максимальное количство заражённых: max_confirmed = 233
# 81. Начинаем тренировать регион России Cheliabinsk oblast
# 	 Максимальное количство заражённых: max_confirmed = 240
# 82. Начинаем тренировать регион России Republic of Chuvashia
# 	 Максимальное количство заражённых: max_confirmed = 383
# 83. Начинаем тренировать регион России Chukotskiy autonomous oblast
# 	 Максимальное количство заражённых: max_confirmed = 12
# 84. Начинаем тренировать регион России Yamalo-Nenetskiy AO
# 	 Максимальное количство заражённых: max_confirmed = 303
# 85. Начинаем тренировать регион России Yaroslavl oblast
# 	 Максимальное количство заражённых: max_confirmed = 342

# %%
subm.to_csv('submission.csv', index=False)

# %% [markdown]
# ## Интересные ссылки
# Научно популярный материал о эпидемиологии https://nplus1.ru/material/2019/12/26/epidemic-math
# Описание полигамных моделей https://en.wikipedia.org/wiki/Compartmental_models_in_epidemiology#The_SEIR_model
# Про инкубационный период https://annals.org/aim/fullarticle/2762808/incubation-period-coronavirus-disease-2019-covid-19-from-publicly-reported
